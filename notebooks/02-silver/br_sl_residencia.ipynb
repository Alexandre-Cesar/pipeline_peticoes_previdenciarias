# %%
from pyspark.sql import functions as f

df = spark.read.table("bronze.residencia")

# %%
df = df.withColumn(
    "cpf",
    f.regexp_replace("cpf", r"\D", "")
)

# %%
df.write.mode("overwrite").saveAsTable("silver.residencia")
